# %% [markdown]
# <a href="https://colab.research.google.com/github/MeghanaCA2904/gca/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

x=[1,2,3]
y=[10,11,12]

plt.plot(x,y)

plt.title("line graph")
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()
